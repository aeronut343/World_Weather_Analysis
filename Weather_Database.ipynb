# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coords = list(lat_lngs)

# %%
# list for holding cities
cities = []
# grab nearest city and store it
for coord in coords:
    city = citipy.nearest_city(coord[0],coord[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 788

# %%
cities
# Out:
# ['bambous virieux',
#  'saldanha',
#  'avarua',
#  'yellowknife',
#  'viligili',
#  'rungata',
#  'busselton',
#  'port augusta',
#  'ndele',
#  'rikitea',
#  'guapi',
#  'butaritari',
#  'santarem',
#  'airai',
#  'praia da vitoria',
#  'bredasdorp',
#  'kapaa',
#  'hobart',
#  'tuktoyaktuk',
#  'ushuaia',
#  'monrovia',
#  'shahr-e babak',
#  'port-cartier',
#  'hunza',
#  'atuona',
#  'ondjiva',
#  'palabuhanratu',
#  'dikson',
#  'lebu',
#  'aitape',
#  'albany',
#  'hermanus',
#  'bereda',
#  'kahului',
#  'arraial do cabo',
#  'karauzyak',
#  'paita',
#  'katangli',
#  'urdzhar',
#  'mar del plata',
#  'champerico',
#  'mataura',
#  'mattru',
#  'sitka',
#  'cape town',
#  'constitucion',
#  'hilo',
#  'najran',
#  'standerton',
#  'hithadhoo',
#  'kodiak',
#  'saint-pierre',
#  'upernavik',
#  'vaini',
#  'vila velha',
#  'punta arenas',
#  'batagay-alyta',
#  'saint george',
#  'bathsheba',
#  'esperance',
#  'qaanaaq',
#  'henties bay',
#  'husavik',
#  'ilhabela',
#  'santa maria',
#  'san andres',
#  'barrow',
#  'lamar',
#  'port hardy',
#  'tukrah',
#  'byron bay',
#  'evensk',
#  'jamestown',
#  'san policarpo',
#  'new norfolk',
#  'santa cruz',
#  'ponta do sol',
#  'taburao',
#  'seara',
#  'karratha',
#  'torbay',
#  'villarrica',
#  'nikolskoye',
#  'tasiilaq',
#  'santa rosa',
#  'itaituba',
#  'puerto ayora',
#  'east london',
#  'rio muerto',
#  'pella',
#  'noumea',
#  'batsfjord',
#  'himora',
#  'carnarvon',
#  'hasaki',
#  'sorvag',
#  'pevek',
#  'vaitupu',
#  'burgeo',
#  'daru',
#  'lolua',
#  'tura',
#  'nizhniy tsasuchey',
#  'ostersund',
#  'okha',
#  'nago',
#  'gat',
#  'mayumba',
#  'port elizabeth',
#  'muisne',
#  'sembe',
#  'shumskiy',
#  'lafiagi',
#  'chokurdakh',
#  'labuan',
#  'petukhovo',
#  'clyde river',
#  'chalons-en-champagne',
#  'san cristobal',
#  'half moon bay',
#  'spasskoye',
#  'vaitape',
#  'north bend',
#  'bartlesville',
#  'khatanga',
#  'victoria',
#  'iralaya',
#  'thompson',
#  'marystown',
#  'kalmunai',
#  'taltal',
#  'santiago de cuba',
#  'longyearbyen',
#  'castro',
#  'tiksi',
#  'richards bay',
#  'chuy',
#  'maniitsoq',
#  'nizhneyansk',
#  'makung',
#  'narsaq',
#  'dien bien',
#  'katherine',
#  'shuyskoye',
#  'labuhan',
#  'taolanaro',
#  'astara',
#  'marcona',
#  'ordzhonikidze',
#  'okato',
#  'sinkat',
#  'fevralsk',
#  'margate',
#  'bethel',
#  'brotas',
#  'conceicao do araguaia',
#  'ninotsminda',
#  'aksu',
#  'bluff',
#  'salinopolis',
#  'tabialan',
#  'ignacio de la llave',
#  'bolungarvik',
#  'sioux lookout',
#  'caibarien',
#  'quang ngai',
#  'aklavik',
#  'kavieng',
#  'shar',
#  'nova granada',
#  'illoqqortoormiut',
#  'sukhoverkovo',
#  'pandan',
#  'vista hermosa',
#  'athabasca',
#  'batagay',
#  'saskylakh',
#  'dekar',
#  'port alfred',
#  'tygda',
#  'alice springs',
#  'arroio grande',
#  'shiojiri',
#  'lakes entrance',
#  'malanje',
#  'abashiri',
#  'cherskiy',
#  'tumannyy',
#  'ust-maya',
#  'araguacu',
#  'sangar',
#  'tsihombe',
#  'manaquiri',
#  'carauari',
#  'marshall',
#  'port lincoln',
#  'mys shmidta',
#  'piranhas',
#  'kosonsoy',
#  'mana',
#  'georgetown',
#  'mineiros',
#  'rawannawi',
#  'lavrentiya',
#  'apostolove',
#  'te anau',
#  'barentsburg',
#  'sur',
#  'saint-philippe',
#  'zhangye',
#  'belaya gora',
#  'mantua',
#  'tomatlan',
#  'tazovskiy',
#  'mount isa',
#  'severo-kurilsk',
#  'poltavka',
#  'bolshoy kamen',
#  'tucurui',
#  'klaksvik',
#  'livingston',
#  'amderma',
#  'santa rosalia',
#  'jacksonville',
#  'hay river',
#  'terni',
#  'takaka',
#  'isangel',
#  'pavelets',
#  'tubruq',
#  'aykhal',
#  'valparaiso',
#  'aksarka',
#  'labrea',
#  'cockburn town',
#  'elizabeth city',
#  'saint-junien',
#  'saint-prosper',
#  'tres arroyos',
#  'devonport',
#  'spas-demensk',
#  'fairbanks',
#  'sal rei',
#  'fiumicino',
#  'sompeta',
#  'toucheng',
#  'vardo',
#  'anadyr',
#  'san matias',
#  'umzimvubu',
#  'bubaque',
#  'vilhena',
#  'alpena',
#  'bukama',
#  'koppang',
#  'orange',
#  'del rio',
#  'yangambi',
#  'paamiut',
#  'fort nelson',
#  'zeya',
#  'kaitangata',
#  'assiniboia',
#  'havoysund',
#  'manggar',
#  'nelson bay',
#  'cootamundra',
#  'saint-agapit',
#  'jinan',
#  'sao filipe',
#  'jalu',
#  'kloulklubed',
#  'morondava',
#  'oistins',
#  'fairview',
#  'vao',
#  'araci',
#  'sumbe',
#  'mahebourg',
#  'sandnessjoen',
#  'snasa',
#  'tessalit',
#  'kinghorn',
#  'norman wells',
#  'huarmey',
#  'souillac',
#  'port hedland',
#  'tuatapere',
#  'okahandja',
#  'tucuman',
#  'nuuk',
#  'shenzhen',
#  'iqaluit',
#  'kilindoni',
#  'rock hill',
#  'college',
#  'beringovskiy',
#  'ribeira grande',
#  'bengkulu',
#  'a',
#  'kamenskoye',
#  'alenquer',
#  'ergani',
#  'mazara del vallo',
#  'salamiyah',
#  'paucartambo',
#  'pangal',
#  'avera',
#  'chifeng',
#  'aquin',
#  'prince rupert',
#  'cidreira',
#  'maceio',
#  'vanavara',
#  'srednekolymsk',
#  'gravdal',
#  'caceres',
#  'sinaloa',
#  'ilulissat',
#  'zhigansk',
#  'bowen',
#  'hong gai',
#  'salalah',
#  'san jose',
#  'doha',
#  'matara',
#  'vallenar',
#  'brigantine',
#  'svetlyy',
#  'barguzin',
#  'namtsy',
#  'pisco',
#  'luderitz',
#  'amga',
#  'hambantota',
#  'novikovo',
#  'gisborne',
#  'dunedin',
#  'sri aman',
#  'xining',
#  'ust-nera',
#  'pocoes',
#  'rio claro',
#  'oyama',
#  'adrar',
#  'lagoa',
#  'belushya guba',
#  'uribia',
#  'veinticinco de mayo',
#  'hami',
#  'antofagasta',
#  'kindberg',
#  'geraldton',
#  'tilichiki',
#  'biak',
#  'rocky mountain house',
#  'kruisfontein',
#  'kardla',
#  'leningradskiy',
#  'pangai',
#  'kieta',
#  'issoudun',
#  'bilma',
#  'deputatskiy',
#  'acari',
#  'kuching',
#  'provideniya',
#  'acarau',
#  'quatre cocos',
#  'port blair',
#  'mizan teferi',
#  'libreville',
#  'marsabit',
#  'mae sai',
#  'falun',
#  'mosquera',
#  'yakeshi',
#  'saleaula',
#  'coquimbo',
#  'mpanda',
#  'vila franca do campo',
#  'mocambique',
#  'kamenskiy',
#  'awjilah',
#  'emerald',
#  'marovoay',
#  'soc trang',
#  'bambanglipuro',
#  'la ronge',
#  'zalantun',
#  'nabire',
#  'axim',
#  'jian',
#  'mugur-aksy',
#  'singapore',
#  'uyemskiy',
#  'mani',
#  'kingaroy',
#  'caucaia',
#  'yining',
#  'houma',
#  'alepe',
#  'felidhoo',
#  'bandar',
#  'khonuu',
#  'ruatoria',
#  'feldbach',
#  'tapaua',
#  'saint anthony',
#  'zyryanka',
#  'cumaribo',
#  'tabory',
#  'mrirt',
#  'wulanhaote',
#  'bolotnoye',
#  'vangaindrano',
#  'puerto escondido',
#  'manokwari',
#  'port-gentil',
#  'tezu',
#  'ugoofaaru',
#  'meulaboh',
#  'udachnyy',
#  'muravlenko',
#  'sindand',
#  'darovskoy',
#  'kasongo-lunda',
#  'sinnamary',
#  'ribas do rio pardo',
#  'siuna',
#  'faanui',
#  'rio grande',
#  'grand centre',
#  'si bun ruang',
#  'indramayu',
#  'caravelas',
#  'shingu',
#  'barbar',
#  'ha giang',
#  'matay',
#  'raudeberg',
#  'kousseri',
#  'goma',
#  'san patricio',
#  'kalemie',
#  'maracas',
#  'bayburt',
#  'sussex',
#  'kumluca',
#  'manta',
#  'bauchi',
#  'mahadday weyne',
#  'skiros',
#  'yulara',
#  'aswan',
#  'berlevag',
#  'soyo',
#  'faya',
#  'turbat',
#  'winona',
#  'belle glade',
#  'guerrero negro',
#  'tautira',
#  'hirado',
#  'chuguyevka',
#  'hobyo',
#  'nome',
#  'cabo san lucas',
#  'gunnedah',
#  'abha',
#  'zhetybay',
#  'taybad',
#  'teya',
#  'saint-francois',
#  'tual',
#  'pozo colorado',
#  'broken hill',
#  'laguna',
#  'plouzane',
#  'grand gaube',
#  'preobrazheniye',
#  'dunkwa',
#  'qarqin',
#  'grand river south east',
#  'katsuura',
#  'egvekinot',
#  'guaimaca',
#  'darhan',
#  'sabha',
#  'san joaquin',
#  'grindavik',
#  'pafos',
#  'igrim',
#  'ulaangom',
#  'yantal',
#  'asau',
#  'hervey bay',
#  'cabedelo',
#  'taywarah',
#  'marsh harbour',
#  'ituporanga',
#  'phek',
#  'smoky lake',
#  'acajutla',
#  'shelburne',
#  'la seyne-sur-mer',
#  'skibotn',
#  'buraydah',
#  'sakaiminato',
#  'moron',
#  'cheremnoye',
#  'samusu',
#  'comodoro rivadavia',
#  'brewster',
#  'diffa',
#  'samarai',
#  'poum',
#  'prince george',
#  'dryden',
#  'mount gambier',
#  'mardin',
#  'batemans bay',
#  'gangotri',
#  'sidi qasim',
#  'camacha',
#  'bontang',
#  'stokmarknes',
#  'karamken',
#  'sankt valentin',
#  'rawson',
#  'lompoc',
#  'iquique',
#  'nanao',
#  'sentyabrskiy',
#  'campana',
#  'the pas',
#  'hualmay',
#  'kavaratti',
#  'fortuna',
#  'miquelon',
#  'coihaique',
#  'boyolangu',
#  'tabuk',
#  'itarema',
#  'villa carlos paz',
#  'kuybysheve',
#  'kashary',
#  'port macquarie',
#  'nanortalik',
#  'bolobo',
#  'khandyga',
#  'kitgum',
#  'ambon',
#  'palmer',
#  'slave lake',
#  'kabwe',
#  'tigzirt',
#  'honiara',
#  'ituni',
#  'alugan',
#  'port keats',
#  'at-bashi',
#  'tyukalinsk',
#  'muros',
#  'yebaishou',
#  'pervomayskiy',
#  'cache creek',
#  'hofn',
#  'phan thiet',
#  'sao joao da barra',
#  'kupang',
#  'jiuquan',
#  'kondinskoye',
#  'kropotkin',
#  'bandrele',
#  'herat',
#  'ngukurr',
#  'falealupo',
#  'natal',
#  'lalibela',
#  'gibara',
#  'kiunga',
#  'shasta lake',
#  'mago',
#  'sturgis',
#  'hvolsvollur',
#  'albert',
#  'yanan',
#  'manoharpur',
#  'goya',
#  'maragogi',
#  'ankazoabo',
#  'manado',
#  'katete',
#  'mayo',
#  'hastings',
#  'cayenne',
#  'salinas',
#  'nguiu',
#  'castelldefels',
#  'hamilton',
#  'lasa',
#  'pokrovsk',
#  'middelharnis',
#  'indiaroba',
#  'katobu',
#  'nagornskiy',
#  'northam',
#  'manbij',
#  'makakilo city',
#  'tatahuicapan',
#  'stawell',
#  'aberdeen',
#  'teofilo otoni',
#  'polunochnoye',
#  'ayan',
#  'capreol',
#  'paradwip',
#  'magadan',
#  'izmalkovo',
#  'rocha',
#  'dudinka',
#  'yenagoa',
#  'alofi',
#  'villazon',
#  'tulun',
#  'dasoguz',
#  'viransehir',
#  'chalon-sur-saone',
#  'sattahip',
#  'khachrod',
#  'naftah',
#  'meyungs',
#  'otane',
#  'aktau',
#  'mingshui',
#  'dolbeau',
#  'portland',
#  'alyangula',
#  'saint-augustin',
#  'inhuma',
#  'cagayan de tawi-tawi',
#  'mindelo',
#  'montepuez',
#  'keetmanshoop',
#  'coahuayana',
#  'changji',
#  'zenzeli',
#  'cururupu',
#  'jumla',
#  'andra',
#  'viedma',
#  'barda',
#  'taos',
#  'saijo',
#  'szczecinek',
#  'ixtapa',
#  'thinadhoo',
#  'aporawan',
#  'sydney',
#  'guaranesia',
#  'los llanos de aridane',
#  'tingo maria',
#  'pontivy',
#  'ust-ilimsk',
#  'san juan',
#  'talnakh',
#  'toungoo',
#  'minchinabad',
#  'hengshui',
#  'prieska',
#  'broome',
#  'ponta delgada',
#  'attawapiskat',
#  'formosa',
#  'orcopampa',
#  'joetsu',
#  'karlskrona',
#  'sao felix do xingu',
#  'aden',
#  'novoagansk',
#  'balimo',
#  'celestun',
#  'itainopolis',
#  'walvis bay',
#  'malaking pulo',
#  'mackay',
#  'yatou',
#  'ahipara',
#  'roald',
#  'porto belo',
#  'nyurba',
#  'codrington',
#  'haines junction',
#  'necochea',
#  'konevo',
#  'west bay',
#  'chapais',
#  'yeppoon',
#  'mitsamiouli',
#  'yershichi',
#  'lamu',
#  'nouadhibou',
#  'marly',
#  'beyneu',
#  'anori',
#  'lapusnicel',
#  'dubovskoye',
#  'baruun-urt',
#  'khorinsk',
#  'agadez',
#  'istanbul',
#  'ketchikan',
#  'dovolnoye',
#  'dubai',
#  'oderzo',
#  'istok',
#  'gainesville',
#  'malmesbury',
#  'ostrovnoy',
#  'wajima',
#  'caluquembe',
#  'arona',
#  'banes',
#  'touros',
#  'sistranda',
#  'breves',
#  'barcelos',
#  'la paz',
#  'parabel',
#  'berbera',
#  'george town',
#  'san julian',
#  'nizhniy kuranakh',
#  'mareeba',
#  'cimarron hills',
#  'aranos',
#  'kalianget',
#  'andenes',
#  'eureka',
#  'skjervoy',
#  'daule',
#  'wattegama',
#  'the valley',
#  'huejuquilla el alto',
#  'teahupoo',
#  'conakry',
#  'dillon',
#  'narodychi',
#  'kobe',
#  'orel-izumrud',
#  'takoradi',
#  'ternovka',
#  'okhotsk',
#  'svobodnyy',
#  'qurbah',
#  'demmin',
#  'yamada',
#  'wahiawa',
#  'bell ville',
#  'olinda',
#  'malwan',
#  'toliary',
#  'tamworth',
#  'hirara',
#  'novoanninskiy',
#  'waingapu',
#  'galle',
#  'matsanga',
#  'namatanai',
#  'manitouwadge',
#  'spirit river',
#  'longkou',
#  'ciudad bolivar',
#  'katha',
#  'meadow lake',
#  'hecelchakan',
#  'bonavista',
#  'kutum',
#  'koungheul',
#  'san carlos de bariloche',
#  'lisakovsk',
#  'ranong',
#  'usinsk',
#  'huancavelica',
#  'temaraia',
#  'burlington',
#  'scarborough']

# %%
# Create an empty list to hold the weather data.
city_data = []

# Define api url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city.replace(" ","+"))
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Date": city_date})
        print(f'completed record {i}')
# If an error is experienced, skip the city.
    except:
         print("City not found. Skipping...")
         pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# bambous+virieux
# completed record 0
# saldanha
# completed record 1
# avarua
# completed record 2
# yellowknife
# completed record 3
# viligili
# City not found. Skipping...
# rungata
# City not found. Skipping...
# busselton
# completed record 6
# port+augusta
# completed record 7
# ndele
# completed record 8
# rikitea
# completed record 9
# guapi
# completed record 10
# butaritari
# completed record 11
# santarem
# completed record 12
# airai
# completed record 13
# praia+da+vitoria
# completed record 14
# bredasdorp
# completed record 15
# kapaa
# completed record 16
# hobart
# completed record 17
# tuktoyaktuk
# completed record 18
# ushuaia
# completed record 19
# monrovia
# completed record 20
# shahr-e+babak
# completed record 21
# port-cartier
# completed record 22
# hunza
# City not found. Skipping...
# atuona
# completed record 24
# ondjiva
# completed record 25
# palabuhanratu
# City not found. Skipping...
# dikson
# completed record 27
# lebu
# completed record 28
# aitape
# completed record 29
# albany
# completed record 30
# hermanus
# completed record 31
# bereda
# completed record 32
# kahului
# completed record 33
# arraial+do+cabo
# completed record 34
# karauzyak
# City not found. Skipping...
# paita
# completed record 36
# katangli
# completed record 37
# urdzhar
# City not found. Skipping...
# mar+del+plata
# completed record 39
# champerico
# completed record 40
# mataura
# completed record 41
# mattru
# completed record 42
# sitka
# completed record 43
# cape+town
# completed record 44
# constitucion
# completed record 45
# hilo
# completed record 46
# najran
# completed record 47
# standerton
# completed record 48
# hithadhoo
# completed record 49
# kodiak
# completed record 50
# saint-pierre
# completed record 51
# upernavik
# completed record 52
# vaini
# completed record 53
# vila+velha
# completed record 54
# punta+arenas
# completed record 55
# batagay-alyta
# completed record 56
# saint+george
# completed record 57
# bathsheba
# completed record 58
# esperance
# completed record 59
# qaanaaq
# completed record 60
# henties+bay
# completed record 61
# husavik
# completed record 62
# ilhabela
# completed record 63
# santa+maria
# completed record 64
# san+andres
# completed record 65
# barrow
# completed record 66
# lamar
# completed record 67
# port+hardy
# completed record 68
# tukrah
# completed record 69
# byron+bay
# completed record 70
# evensk
# completed record 71
# jamestown
# completed record 72
# san+policarpo
# completed record 73
# new+norfolk
# completed record 74
# santa+cruz
# completed record 75
# ponta+do+sol
# completed record 76
# taburao
# City not found. Skipping...
# seara
# completed record 78
# karratha
# completed record 79
# torbay
# completed record 80
# villarrica
# completed record 81
# nikolskoye
# completed record 82
# tasiilaq
# completed record 83
# santa+rosa
# completed record 84
# itaituba
# completed record 85
# puerto+ayora
# completed record 86
# east+london
# completed record 87
# rio+muerto
# completed record 88
# pella
# completed record 89
# noumea
# completed record 90
# batsfjord
# completed record 91
# himora
# City not found. Skipping...
# carnarvon
# completed record 93
# hasaki
# completed record 94
# sorvag
# City not found. Skipping...
# pevek
# completed record 96
# vaitupu
# City not found. Skipping...
# burgeo
# completed record 98
# daru
# completed record 99
# lolua
# City not found. Skipping...
# tura
# completed record 101
# nizhniy+tsasuchey
# completed record 102
# ostersund
# completed record 103
# okha
# completed record 104
# nago
# completed record 105
# gat
# completed record 106
# mayumba
# completed record 107
# port+elizabeth
# completed record 108
# muisne
# completed record 109
# sembe
# completed record 110
# shumskiy
# completed record 111
# lafiagi
# completed record 112
# chokurdakh
# completed record 113
# labuan
# completed record 114
# petukhovo
# completed record 115
# clyde+river
# completed record 116
# chalons-en-champagne
# completed record 117
# san+cristobal
# completed record 118
# half+moon+bay
# completed record 119
# spasskoye
# completed record 120
# vaitape
# completed record 121
# north+bend
# completed record 122
# bartlesville
# completed record 123
# khatanga
# completed record 124
# victoria
# completed record 125
# iralaya
# completed record 126
# thompson
# completed record 127
# marystown
# completed record 128
# kalmunai
# completed record 129
# taltal
# completed record 130
# santiago+de+cuba
# completed record 131
# longyearbyen
# completed record 132
# castro
# completed record 133
# tiksi
# completed record 134
# richards+bay
# completed record 135
# chuy
# completed record 136
# maniitsoq
# completed record 137
# nizhneyansk
# City not found. Skipping...
# makung
# City not found. Skipping...
# narsaq
# completed record 140
# dien+bien
# City not found. Skipping...
# katherine
# completed record 142
# shuyskoye
# completed record 143
# labuhan
# completed record 144
# taolanaro
# City not found. Skipping...
# astara
# completed record 146
# marcona
# City not found. Skipping...
# ordzhonikidze
# completed record 148
# okato
# completed record 149
# sinkat
# City not found. Skipping...
# fevralsk
# City not found. Skipping...
# margate
# completed record 152
# bethel
# completed record 153
# brotas
# completed record 154
# conceicao+do+araguaia
# completed record 155
# ninotsminda
# completed record 156
# aksu
# completed record 157
# bluff
# completed record 158
# salinopolis
# completed record 159
# tabialan
# City not found. Skipping...
# ignacio+de+la+llave
# completed record 161
# bolungarvik
# City not found. Skipping...
# sioux+lookout
# completed record 163
# caibarien
# completed record 164
# quang+ngai
# completed record 165
# aklavik
# completed record 166
# kavieng
# completed record 167
# shar
# completed record 168
# nova+granada
# completed record 169
# illoqqortoormiut
# City not found. Skipping...
# sukhoverkovo
# City not found. Skipping...
# pandan
# completed record 172
# vista+hermosa
# completed record 173
# athabasca
# completed record 174
# batagay
# completed record 175
# saskylakh
# completed record 176
# dekar
# completed record 177
# port+alfred
# completed record 178
# tygda
# completed record 179
# alice+springs
# completed record 180
# arroio+grande
# completed record 181
# shiojiri
# completed record 182
# lakes+entrance
# completed record 183
# malanje
# completed record 184
# abashiri
# completed record 185
# cherskiy
# completed record 186
# tumannyy
# City not found. Skipping...
# ust-maya
# completed record 188
# araguacu
# completed record 189
# sangar
# completed record 190
# tsihombe
# City not found. Skipping...
# manaquiri
# completed record 192
# carauari
# completed record 193
# marshall
# completed record 194
# port+lincoln
# completed record 195
# mys+shmidta
# City not found. Skipping...
# piranhas
# completed record 197
# kosonsoy
# completed record 198
# mana
# completed record 199
# georgetown
# completed record 200
# mineiros
# completed record 201
# rawannawi
# City not found. Skipping...
# lavrentiya
# completed record 203
# apostolove
# completed record 204
# te+anau
# completed record 205
# barentsburg
# City not found. Skipping...
# sur
# completed record 207
# saint-philippe
# completed record 208
# zhangye
# completed record 209
# belaya+gora
# completed record 210
# mantua
# completed record 211
# tomatlan
# completed record 212
# tazovskiy
# completed record 213
# mount+isa
# completed record 214
# severo-kurilsk
# completed record 215
# poltavka
# completed record 216
# bolshoy+kamen
# completed record 217
# tucurui
# completed record 218
# klaksvik
# completed record 219
# livingston
# completed record 220
# amderma
# City not found. Skipping...
# santa+rosalia
# completed record 222
# jacksonville
# completed record 223
# hay+river
# completed record 224
# terni
# completed record 225
# takaka
# completed record 226
# isangel
# completed record 227
# pavelets
# completed record 228
# tubruq
# City not found. Skipping...
# aykhal
# completed record 230
# valparaiso
# completed record 231
# aksarka
# completed record 232
# labrea
# completed record 233
# cockburn+town
# completed record 234
# elizabeth+city
# completed record 235
# saint-junien
# completed record 236
# saint-prosper
# completed record 237
# tres+arroyos
# completed record 238
# devonport
# completed record 239
# spas-demensk
# completed record 240
# fairbanks
# completed record 241
# sal+rei
# completed record 242
# fiumicino
# completed record 243
# sompeta
# completed record 244
# toucheng
# completed record 245
# vardo
# completed record 246
# anadyr
# completed record 247
# san+matias
# completed record 248
# umzimvubu
# City not found. Skipping...
# bubaque
# completed record 250
# vilhena
# completed record 251
# alpena
# completed record 252
# bukama
# completed record 253
# koppang
# completed record 254
# orange
# completed record 255
# del+rio
# completed record 256
# yangambi
# completed record 257
# paamiut
# completed record 258
# fort+nelson
# completed record 259
# zeya
# completed record 260
# kaitangata
# completed record 261
# assiniboia
# completed record 262
# havoysund
# completed record 263
# manggar
# completed record 264
# nelson+bay
# completed record 265
# cootamundra
# completed record 266
# saint-agapit
# completed record 267
# jinan
# completed record 268
# sao+filipe
# completed record 269
# jalu
# completed record 270
# kloulklubed
# completed record 271
# morondava
# completed record 272
# oistins
# completed record 273
# fairview
# completed record 274
# vao
# completed record 275
# araci
# completed record 276
# sumbe
# completed record 277
# mahebourg
# completed record 278
# sandnessjoen
# completed record 279
# snasa
# completed record 280
# tessalit
# completed record 281
# kinghorn
# completed record 282
# norman+wells
# completed record 283
# huarmey
# completed record 284
# souillac
# completed record 285
# port+hedland
# completed record 286
# tuatapere
# completed record 287
# okahandja
# completed record 288
# tucuman
# completed record 289
# nuuk
# completed record 290
# shenzhen
# completed record 291
# iqaluit
# completed record 292
# kilindoni
# completed record 293
# rock+hill
# completed record 294
# college
# completed record 295
# beringovskiy
# completed record 296
# ribeira+grande
# completed record 297
# bengkulu
# completed record 298
# a
# City not found. Skipping...
# kamenskoye
# City not found. Skipping...
# alenquer
# completed record 301
# ergani
# completed record 302
# mazara+del+vallo
# completed record 303
# salamiyah
# completed record 304
# paucartambo
# City not found. Skipping...
# pangal
# completed record 306
# avera
# completed record 307
# chifeng
# completed record 308
# aquin
# completed record 309
# prince+rupert
# completed record 310
# cidreira
# completed record 311
# maceio
# completed record 312
# vanavara
# completed record 313
# srednekolymsk
# completed record 314
# gravdal
# completed record 315
# caceres
# completed record 316
# sinaloa
# completed record 317
# ilulissat
# completed record 318
# zhigansk
# completed record 319
# bowen
# completed record 320
# hong+gai
# completed record 321
# salalah
# completed record 322
# san+jose
# completed record 323
# doha
# completed record 324
# matara
# completed record 325
# vallenar
# completed record 326
# brigantine
# completed record 327
# svetlyy
# completed record 328
# barguzin
# completed record 329
# namtsy
# completed record 330
# pisco
# completed record 331
# luderitz
# completed record 332
# amga
# completed record 333
# hambantota
# completed record 334
# novikovo
# completed record 335
# gisborne
# completed record 336
# dunedin
# completed record 337
# sri+aman
# completed record 338
# xining
# completed record 339
# ust-nera
# completed record 340
# pocoes
# completed record 341
# rio+claro
# completed record 342
# oyama
# completed record 343
# adrar
# completed record 344
# lagoa
# completed record 345
# belushya+guba
# City not found. Skipping...
# uribia
# completed record 347
# veinticinco+de+mayo
# completed record 348
# hami
# completed record 349
# antofagasta
# completed record 350
# kindberg
# completed record 351
# geraldton
# completed record 352
# tilichiki
# completed record 353
# biak
# completed record 354
# rocky+mountain+house
# completed record 355
# kruisfontein
# completed record 356
# kardla
# completed record 357
# leningradskiy
# completed record 358
# pangai
# completed record 359
# kieta
# completed record 360
# issoudun
# completed record 361
# bilma
# completed record 362
# deputatskiy
# completed record 363
# acari
# completed record 364
# kuching
# completed record 365
# provideniya
# completed record 366
# acarau
# completed record 367
# quatre+cocos
# completed record 368
# port+blair
# completed record 369
# mizan+teferi
# completed record 370
# libreville
# completed record 371
# marsabit
# completed record 372
# mae+sai
# completed record 373
# falun
# completed record 374
# mosquera
# completed record 375
# yakeshi
# completed record 376
# saleaula
# City not found. Skipping...
# coquimbo
# completed record 378
# mpanda
# completed record 379
# vila+franca+do+campo
# completed record 380
# mocambique
# City not found. Skipping...
# kamenskiy
# completed record 382
# awjilah
# completed record 383
# emerald
# completed record 384
# marovoay
# completed record 385
# soc+trang
# completed record 386
# bambanglipuro
# completed record 387
# la+ronge
# completed record 388
# zalantun
# completed record 389
# nabire
# completed record 390
# axim
# completed record 391
# jian
# completed record 392
# mugur-aksy
# completed record 393
# singapore
# completed record 394
# uyemskiy
# completed record 395
# mani
# completed record 396
# kingaroy
# completed record 397
# caucaia
# completed record 398
# yining
# completed record 399
# houma
# completed record 400
# alepe
# completed record 401
# felidhoo
# City not found. Skipping...
# bandar
# completed record 403
# khonuu
# City not found. Skipping...
# ruatoria
# City not found. Skipping...
# feldbach
# completed record 406
# tapaua
# City not found. Skipping...
# saint+anthony
# completed record 408
# zyryanka
# completed record 409
# cumaribo
# City not found. Skipping...
# tabory
# completed record 411
# mrirt
# City not found. Skipping...
# wulanhaote
# City not found. Skipping...
# bolotnoye
# completed record 414
# vangaindrano
# completed record 415
# puerto+escondido
# completed record 416
# manokwari
# completed record 417
# port-gentil
# completed record 418
# tezu
# completed record 419
# ugoofaaru
# completed record 420
# meulaboh
# completed record 421
# udachnyy
# completed record 422
# muravlenko
# completed record 423
# sindand
# City not found. Skipping...
# darovskoy
# completed record 425
# kasongo-lunda
# completed record 426
# sinnamary
# completed record 427
# ribas+do+rio+pardo
# completed record 428
# siuna
# completed record 429
# faanui
# completed record 430
# rio+grande
# completed record 431
# grand+centre
# City not found. Skipping...
# si+bun+ruang
# completed record 433
# indramayu
# completed record 434
# caravelas
# completed record 435
# shingu
# completed record 436
# barbar
# City not found. Skipping...
# ha+giang
# completed record 438
# matay
# completed record 439
# raudeberg
# completed record 440
# kousseri
# completed record 441
# goma
# completed record 442
# san+patricio
# completed record 443
# kalemie
# completed record 444
# maracas
# completed record 445
# bayburt
# completed record 446
# sussex
# completed record 447
# kumluca
# completed record 448
# manta
# completed record 449
# bauchi
# completed record 450
# mahadday+weyne
# City not found. Skipping...
# skiros
# City not found. Skipping...
# yulara
# completed record 453
# aswan
# completed record 454
# berlevag
# completed record 455
# soyo
# completed record 456
# faya
# completed record 457
# turbat
# completed record 458
# winona
# completed record 459
# belle+glade
# completed record 460
# guerrero+negro
# completed record 461
# tautira
# completed record 462
# hirado
# completed record 463
# chuguyevka
# completed record 464
# hobyo
# completed record 465
# nome
# completed record 466
# cabo+san+lucas
# completed record 467
# gunnedah
# completed record 468
# abha
# completed record 469
# zhetybay
# City not found. Skipping...
# taybad
# completed record 471
# teya
# completed record 472
# saint-francois
# completed record 473
# tual
# completed record 474
# pozo+colorado
# completed record 475
# broken+hill
# completed record 476
# laguna
# completed record 477
# plouzane
# completed record 478
# grand+gaube
# completed record 479
# preobrazheniye
# completed record 480
# dunkwa
# completed record 481
# qarqin
# completed record 482
# grand+river+south+east
# City not found. Skipping...
# katsuura
# completed record 484
# egvekinot
# completed record 485
# guaimaca
# completed record 486
# darhan
# completed record 487
# sabha
# completed record 488
# san+joaquin
# completed record 489
# grindavik
# completed record 490
# pafos
# completed record 491
# igrim
# completed record 492
# ulaangom
# completed record 493
# yantal
# completed record 494
# asau
# completed record 495
# hervey+bay
# completed record 496
# cabedelo
# completed record 497
# taywarah
# completed record 498
# marsh+harbour
# completed record 499
# ituporanga
# completed record 500
# phek
# completed record 501
# smoky+lake
# completed record 502
# acajutla
# completed record 503
# shelburne
# completed record 504
# la+seyne-sur-mer
# completed record 505
# skibotn
# completed record 506
# buraydah
# completed record 507
# sakaiminato
# completed record 508
# moron
# completed record 509
# cheremnoye
# completed record 510
# samusu
# City not found. Skipping...
# comodoro+rivadavia
# completed record 512
# brewster
# completed record 513
# diffa
# completed record 514
# samarai
# completed record 515
# poum
# completed record 516
# prince+george
# completed record 517
# dryden
# completed record 518
# mount+gambier
# completed record 519
# mardin
# completed record 520
# batemans+bay
# completed record 521
# gangotri
# City not found. Skipping...
# sidi+qasim
# City not found. Skipping...
# camacha
# completed record 524
# bontang
# completed record 525
# stokmarknes
# completed record 526
# karamken
# City not found. Skipping...
# sankt+valentin
# completed record 528
# rawson
# completed record 529
# lompoc
# completed record 530
# iquique
# completed record 531
# nanao
# completed record 532
# sentyabrskiy
# City not found. Skipping...
# campana
# completed record 534
# the+pas
# completed record 535
# hualmay
# completed record 536
# kavaratti
# completed record 537
# fortuna
# completed record 538
# miquelon
# completed record 539
# coihaique
# completed record 540
# boyolangu
# completed record 541
# tabuk
# completed record 542
# itarema
# completed record 543
# villa+carlos+paz
# completed record 544
# kuybysheve
# completed record 545
# kashary
# completed record 546
# port+macquarie
# completed record 547
# nanortalik
# completed record 548
# bolobo
# completed record 549
# khandyga
# completed record 550
# kitgum
# completed record 551
# ambon
# completed record 552
# palmer
# completed record 553
# slave+lake
# completed record 554
# kabwe
# completed record 555
# tigzirt
# completed record 556
# honiara
# completed record 557
# ituni
# City not found. Skipping...
# alugan
# completed record 559
# port+keats
# completed record 560
# at-bashi
# completed record 561
# tyukalinsk
# completed record 562
# muros
# completed record 563
# yebaishou
# completed record 564
# pervomayskiy
# completed record 565
# cache+creek
# completed record 566
# hofn
# completed record 567
# phan+thiet
# completed record 568
# sao+joao+da+barra
# completed record 569
# kupang
# completed record 570
# jiuquan
# completed record 571
# kondinskoye
# completed record 572
# kropotkin
# completed record 573
# bandrele
# completed record 574
# herat
# completed record 575
# ngukurr
# City not found. Skipping...
# falealupo
# City not found. Skipping...
# natal
# completed record 578
# lalibela
# completed record 579
# gibara
# completed record 580
# kiunga
# completed record 581
# shasta+lake
# completed record 582
# mago
# completed record 583
# sturgis
# completed record 584
# hvolsvollur
# completed record 585
# albert
# completed record 586
# yanan
# City not found. Skipping...
# manoharpur
# completed record 588
# goya
# completed record 589
# maragogi
# completed record 590
# ankazoabo
# completed record 591
# manado
# completed record 592
# katete
# completed record 593
# mayo
# completed record 594
# hastings
# completed record 595
# cayenne
# completed record 596
# salinas
# completed record 597
# nguiu
# City not found. Skipping...
# castelldefels
# completed record 599
# hamilton
# completed record 600
# lasa
# completed record 601
# pokrovsk
# completed record 602
# middelharnis
# completed record 603
# indiaroba
# completed record 604
# katobu
# completed record 605
# nagornskiy
# completed record 606
# northam
# completed record 607
# manbij
# completed record 608
# makakilo+city
# completed record 609
# tatahuicapan
# completed record 610
# stawell
# completed record 611
# aberdeen
# completed record 612
# teofilo+otoni
# completed record 613
# polunochnoye
# completed record 614
# ayan
# completed record 615
# capreol
# completed record 616
# paradwip
# City not found. Skipping...
# magadan
# completed record 618
# izmalkovo
# completed record 619
# rocha
# completed record 620
# dudinka
# completed record 621
# yenagoa
# completed record 622
# alofi
# completed record 623
# villazon
# completed record 624
# tulun
# completed record 625
# dasoguz
# completed record 626
# viransehir
# completed record 627
# chalon-sur-saone
# completed record 628
# sattahip
# completed record 629
# khachrod
# completed record 630
# naftah
# City not found. Skipping...
# meyungs
# City not found. Skipping...
# otane
# completed record 633
# aktau
# completed record 634
# mingshui
# completed record 635
# dolbeau
# City not found. Skipping...
# portland
# completed record 637
# alyangula
# completed record 638
# saint-augustin
# completed record 639
# inhuma
# completed record 640
# cagayan+de+tawi-tawi
# City not found. Skipping...
# mindelo
# completed record 642
# montepuez
# completed record 643
# keetmanshoop
# completed record 644
# coahuayana
# completed record 645
# changji
# completed record 646
# zenzeli
# completed record 647
# cururupu
# completed record 648
# jumla
# completed record 649
# andra
# completed record 650
# viedma
# completed record 651
# barda
# completed record 652
# taos
# completed record 653
# saijo
# completed record 654
# szczecinek
# completed record 655
# ixtapa
# completed record 656
# thinadhoo
# completed record 657
# aporawan
# City not found. Skipping...
# sydney
# completed record 659
# guaranesia
# completed record 660
# los+llanos+de+aridane
# completed record 661
# tingo+maria
# completed record 662
# pontivy
# completed record 663
# ust-ilimsk
# completed record 664
# san+juan
# completed record 665
# talnakh
# completed record 666
# toungoo
# City not found. Skipping...
# minchinabad
# completed record 668
# hengshui
# completed record 669
# prieska
# completed record 670
# broome
# completed record 671
# ponta+delgada
# completed record 672
# attawapiskat
# City not found. Skipping...
# formosa
# completed record 674
# orcopampa
# completed record 675
# joetsu
# completed record 676
# karlskrona
# completed record 677
# sao+felix+do+xingu
# completed record 678
# aden
# completed record 679
# novoagansk
# completed record 680
# balimo
# City not found. Skipping...
# celestun
# completed record 682
# itainopolis
# completed record 683
# walvis+bay
# completed record 684
# malaking+pulo
# City not found. Skipping...
# mackay
# completed record 686
# yatou
# completed record 687
# ahipara
# completed record 688
# roald
# completed record 689
# porto+belo
# completed record 690
# nyurba
# completed record 691
# codrington
# completed record 692
# haines+junction
# completed record 693
# necochea
# completed record 694
# konevo
# completed record 695
# west+bay
# completed record 696
# chapais
# completed record 697
# yeppoon
# completed record 698
# mitsamiouli
# completed record 699
# yershichi
# completed record 700
# lamu
# completed record 701
# nouadhibou
# completed record 702
# marly
# completed record 703
# beyneu
# completed record 704
# anori
# completed record 705
# lapusnicel
# completed record 706
# dubovskoye
# completed record 707
# baruun-urt
# completed record 708
# khorinsk
# completed record 709
# agadez
# completed record 710
# istanbul
# completed record 711
# ketchikan
# completed record 712
# dovolnoye
# completed record 713
# dubai
# completed record 714
# oderzo
# completed record 715
# istok
# completed record 716
# gainesville
# completed record 717
# malmesbury
# completed record 718
# ostrovnoy
# completed record 719
# wajima
# completed record 720
# caluquembe
# completed record 721
# arona
# completed record 722
# banes
# completed record 723
# touros
# completed record 724
# sistranda
# completed record 725
# breves
# completed record 726
# barcelos
# completed record 727
# la+paz
# completed record 728
# parabel
# completed record 729
# berbera
# completed record 730
# george+town
# completed record 731
# san+julian
# completed record 732
# nizhniy+kuranakh
# completed record 733
# mareeba
# completed record 734
# cimarron+hills
# completed record 735
# aranos
# completed record 736
# kalianget
# completed record 737
# andenes
# completed record 738
# eureka
# completed record 739
# skjervoy
# completed record 740
# daule
# completed record 741
# wattegama
# completed record 742
# the+valley
# completed record 743
# huejuquilla+el+alto
# completed record 744
# teahupoo
# completed record 745
# conakry
# completed record 746
# dillon
# completed record 747
# narodychi
# completed record 748
# kobe
# completed record 749
# orel-izumrud
# completed record 750
# takoradi
# completed record 751
# ternovka
# completed record 752
# okhotsk
# completed record 753
# svobodnyy
# completed record 754
# qurbah
# City not found. Skipping...
# demmin
# completed record 756
# yamada
# completed record 757
# wahiawa
# completed record 758
# bell+ville
# completed record 759
# olinda
# completed record 760
# malwan
# City not found. Skipping...
# toliary
# City not found. Skipping...
# tamworth
# completed record 763
# hirara
# completed record 764
# novoanninskiy
# completed record 765
# waingapu
# completed record 766
# galle
# completed record 767
# matsanga
# City not found. Skipping...
# namatanai
# completed record 769
# manitouwadge
# completed record 770
# spirit+river
# completed record 771
# longkou
# completed record 772
# ciudad+bolivar
# completed record 773
# katha
# City not found. Skipping...
# meadow+lake
# completed record 775
# hecelchakan
# completed record 776
# bonavista
# completed record 777
# kutum
# completed record 778
# koungheul
# completed record 779
# san+carlos+de+bariloche
# completed record 780
# lisakovsk
# completed record 781
# ranong
# completed record 782
# usinsk
# completed record 783
# huancavelica
# completed record 784
# temaraia
# City not found. Skipping...
# burlington
# completed record 786
# scarborough
# completed record 787
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Bambous Virieux      MU -20.3428   57.7575     69.22        83          20
# 1         Saldanha      ZA -33.0117   17.9442     55.45        89         100
# 2           Avarua      CK -21.2078 -159.7750     75.25        60          75
# 3      Yellowknife      CA  62.4560 -114.3525     59.52        55          20
# 4        Busselton      AU -33.6500  115.3333     56.08        85           4
#
#    Wind Speed Current Description                 Date
# 0       13.80          light rain  2021-08-18 00:17:58
# 1        9.08     overcast clouds  2021-08-18 00:17:59
# 2       13.80       broken clouds  2021-08-18 00:17:59
# 3       11.50          few clouds  2021-08-18 00:17:36
# 4        3.96           clear sky  2021-08-18 00:18:00

# %%
# Create output file
output_file = "Weather_Database/WeatherPy_Database.csv"
# Export to csv
city_data_df.to_csv(output_file,index_label="City_ID")
